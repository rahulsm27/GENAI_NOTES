# %%
# using VAE for image embedingss

# %% [markdown]
# ![Alt text](image-1.png)

# %% [markdown]
# ![Alt text](image-2.png)

# %%
# using sentence encoder for text embedings

# %% [markdown]
# ![Alt text](image-3.png)

# %%
# calculating distance

# %% [markdown]
# ![Alt text](image-4.png)

# %% [markdown]
# ![Alt text](image-5.png)

# %% [markdown]
# # manhathan is (x1-x2) + (y1-y2)

# %% [markdown]
# ![Alt text](image-6.png)

# %% [markdown]
# <!-- The governing rules for the cross product are defined by the problem of computing area from vectors. As you saw from this section, the right hand rule rolled out naturally from us trying to calculate the area.
# You can re-derive the other rules from the logic we used here (y times z yields an x value, z times x yields a y value, etc.)
# The cross product is all about multiplying quantities from different dimensions into something useful. In this article, we multiplied two numbers from different dimensions (one from the x-axis and another from the y-axis) to get area.
# The cross product is a vector because it is useful. For example, in physics we might want to know the flux (how much ‘stuff’ is going through a surface) of a certain surface — which requires an area vector and not just a scalar value.
# The cross product is not just some black box algorithm. The cross product is defined the way it is because it has to be, for the problems that it was designed to solve. I hope my short example made this clear. -->

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# dot is dependednt on magnitude.. two ways to calculate.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
