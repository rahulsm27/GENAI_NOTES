# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Alt text](image-6.png)

# %% [markdown]
# ![Alt text](image-7.png)

# %% [markdown]
# ![Alt text](image-8.png)

# %%
# Feedback funnction structure for answer releavance

# %% [markdown]
# ![Alt text](image-5.png)

# %% [markdown]
# ![Alt text](image-11.png)

# %%
# CONTEXT RELEVANCE

# %% [markdown]
# ![Alt text](image-12.png)

# %% [markdown]
# ![Alt text](image-13.png)

# %%
# Takes intermediate output (context as well)

# %% [markdown]
# ![Alt text](image-14.png)

# %%
# with and without COT reason method

# %% [markdown]
# ![Alt text](image-15.png)

# %%
# with cot
# provides supporting evidence

# %% [markdown]
# ![Alt text](image-16.png)

# %% [markdown]
# ![Alt text](image-17.png)

# %%
# Groundedness

# %% [markdown]
# ![Alt text](image-18.png)

# %% [markdown]
# # failure mode generally context is not relavant due to context size and
#
# # if context releavance increase other score also incrase

# %% [markdown]
# ![Alt text](image-19.png)

# %%
## Different types of feedback
# In this we have used LLM (Open AI ) for feedback

# Different types of feedback function


# Groun truth evals -> Expert provide rating for the output
# Human users of the app provide rating -> not expert
# Traditional NLP  evals -> Rouge, Bleu

# %% [markdown]
# ![Alt text](image-20.png)

# %%
# In course three options. BUt there are many options for evaluation

# %% [markdown]
# ![Alt text](image-21.png)
