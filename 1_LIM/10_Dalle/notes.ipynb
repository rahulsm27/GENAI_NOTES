# %%
"""
The diffusion prior is transformer (decoder) - it takes order sequence of 

The decoder is a diffusion model like stable diffusion unet..which get conditioned on clip image embeddings

See orignal paper for better understanding

"""

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Alt text](image.png)

# %% [markdown]
# ![Alt text](image-1.png)

# %% [markdown]
# ![Alt text](image-2.png)
